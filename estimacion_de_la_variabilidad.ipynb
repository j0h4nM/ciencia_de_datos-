# %% [markdown]
# <a href="https://colab.research.google.com/github/j0h4nM/ciencia_de_datos-/blob/main/estimacion_de_la_variabilidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. varianza
# ## 2. desviacion estandar
# ## 3. desviacion media absoluta
# ## 4. desviacion absoluta de la media (MAD)
# ## 5. rango
# ## 6. estadistica ordinal
# ## 7. porcentil
# ## 8. rango intercuartil (IQR)

# %%
#CARGAR DATO DESDE GOGLE DRIVE
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install statsmodels

# !pip install wquantiles

# %%
import pandas as pd
import numpy as np
from statsmodels import robust
import matplotlib.pyplot as plt
import wquantiles
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/CIENCIAS DE DATOS /state.csv")

# %%
data.sample(3)
# Out:
#             State  Population  Murder.Rate Abbreviation
# 4      California    37253956          4.4           CA
# 19       Maryland     5773552          6.1           MD
# 28  New Hampshire     1316470          0.9           NH

# %%
#CUALES RUTAS SE TRABAJAN
data.columns
# Out:
# Index(['State', 'Population', 'Murder.Rate', 'Abbreviation'], dtype='object')

# %%
data.describe()
# Out:
#          Population  Murder.Rate
# count  5.000000e+01    50.000000
# mean   6.162876e+06     4.066000
# std    6.848235e+06     1.915736
# min    5.636260e+05     0.900000
# 25%    1.833004e+06     2.425000
# 50%    4.436370e+06     4.000000
# 75%    6.680312e+06     5.550000
# max    3.725396e+07    10.300000

# %%
#general calculo de desviacion estandar y cuantiles
data["P opulation"].std()
# Out:
# 6848235.347401142

# %%
M_poblacion=data.groupby(["Population"])["State"].max()

# %%
robust.scale.mad(data.Population)
# Out:
# np.float64(3849876.1459979336)

# %%
data["Murder.rate"].quantile(0.05,0.25,0.75,0.95)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Murder.rate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-3472ec45c2ed> in <cell line: 0>()
# ----> 1 data["Murder.rate"].quantile(0.05,0.25,0.75,0.95)
#
# ...
